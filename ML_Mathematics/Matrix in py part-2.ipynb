# %%
import numpy as np

# %% [markdown]
# **Matrix Addition**

# %% [markdown]
# **Two Matrices can be added only if they have the same shape**

# %%
#creating the two matrices
a = np.array([[2,3],[4,5]])
b = np.array([[6,7],[8,9]])

# %%
print(a)
a.shape
# Out:
# [[2 3]
#  [4 5]]
# (2, 2)

# %%
print(b)
a.shape
# Out:
# [[6 7]
#  [8 9]]
# (2, 2)

# %% [markdown]
# **Addition of two matrices**

# %%
sum = a+b
print(sum)
# Out:
# [[ 8 10]
#  [12 14]]

# %%
#cerating two matrices with random variables
m1 = np.random.randint(10,size=(3,3))
m2 = np.random.randint(20,size=(3,3))

# %%
print(m1)
print(m2)
# Out:
# [[0 1 4]
#  [0 4 0]
#  [4 4 9]]
# [[16  9 18]
#  [ 3  1 18]
#  [17  6 14]]

# %%
sum1 = m1+m2
print(sum1)
# Out:
# [[16 10 22]
#  [ 3  5 18]
#  [21 10 23]]

# %%
sum2 =np.add(m1,m2)
sum2
# Out:
# array([[16, 10, 22],
#        [ 3,  5, 18],
#        [21, 10, 23]])

# %%
m3 = np.random.randint(10,size=(3,3))
m4 = np.random.randint(20,size=(3,4))

# %%
print(m3)
print(m4)
# Out:
# [[9 4 1]
#  [2 8 2]
#  [7 0 0]]
# [[13  8 16 18]
#  [ 9 15  1  8]
#  [11 14  5  1]]

# %%
sum3 = m3+m4
sum3 
# we got error because of shape of m3,m4 matrices is different
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b39c2f6c1b99> in <module>
# ----> 1 sum3 = m3+m4
#       2 sum3
#
# ValueError: operands could not be broadcast together with shapes (3,3) (3,4)

# %% [markdown]
# **Subtraction of two matrices**

# %%
sub=b-a
print(sub)
# Out:
# [[4 4]
#  [4 4]]

# %%
#cerating two matrices with random variables
m5 = np.random.randint(10,size=(3,3))
m6 = np.random.randint(20,size=(3,3))

# %%
print(m5)
print(m6)
# Out:
# [[0 7 1]
#  [2 4 1]
#  [4 5 1]]
# [[18 14 12]
#  [ 5 13 14]
#  [ 7 17 13]]

# %%
sub2 = m5-m6
sub2
# Out:
# array([[-18,  -7, -11],
#        [ -3,  -9, -13],
#        [ -3, -12, -12]])

# %% [markdown]
# **Multiplication of matrices by a scaler**

# %%
x = 5
y = np.array([2,3,4])
mul = x*y
print(mul)
# Out:
# [10 15 20]

# %%
x1 = 5
y1 = np.random.randint(10, size=(4,4))
mul1 = x1*y1
mul1
# Out:
# array([[ 5, 15, 25, 35],
#        [ 0, 35, 10, 30],
#        [25, 20, 20,  0],
#        [15, 35, 20,  0]])

# %% [markdown]
# **Multiplying the two matrices**

# %%
m7 = np.random.randint(5,size=(3,3))
m8 = np.random.randint(5,size=(3,4))

# %%
print(m7)
print(m8)
# Out:
# [[3 3 2]
#  [1 3 3]
#  [0 1 3]]
# [[1 0 2 3]
#  [1 3 3 1]
#  [4 1 2 4]]
# (3, 4)

# %%
m7.shape
# Out:
# (3, 3)

# %%
m8.shape
# Out:
# (3, 4)

# %%
product = np.dot(m7,m8)
print(product)
# Out:
# [[14 11 19 20]
#  [16 12 17 18]
#  [13  6  9 13]]

# %%
m9 = np.random.randint(5,size=(3,3))
m10 = np.random.randint(5,size=(3,3))

# %%
print(m9)
print(m10)
# Out:
# [[4 0 0]
#  [0 3 4]
#  [1 0 1]]
# [[3 0 2]
#  [2 4 0]
#  [0 1 4]]

# %%
mul2 = np.multiply(m9,m10)
mul2
# Out:
# array([[12,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  0,  4]])
