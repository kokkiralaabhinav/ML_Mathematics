# %%
import numpy as np

# %% [markdown]
# **DOT PRODUCT OF TWO VAECTORS**

# %%
a = np.array([2,3])
b = np.array([4,4])
a_dot_b = np.dot(a,b)

# %%
print(a_dot_b)
# Out:
# 20

# %%
c = np.array([40,20,35])
d = np.array([53,24,68])
c_dot_d = np.dot(c,d)
c_dot_d
# Out:
# 4980

# %% [markdown]
# **Cross product of two vectors**

# %%
a = np.array([2,3])
b = np.array([4,4])
a_cross_b = np.cross(a,b)
a_cross_b
# Out:
# array(-4)

# %%
print(a_cross_b)
# Out:
# -4

# %%
from numpy.core.multiarray import packbits
c = np.array([5,10,20])
d = np.array([18,32,50])
c_cross_d = np.cross(c,d)
c_cross_d
# Out:
# array([-140,  110,  -20])

# %%
print(c_cross_d)
# Out:
# [-140  110  -20]

# %% [markdown]
# **Projection of 'a' vector on 'v' vector**

# %%
a = np.array([2,5])
v = np.array([8,-6])

#magnitude of 'v' vector
magnitude_of_v = np.sqrt(sum(v**2))
proj_of_a_on_v = (np.dot(a,v)/magnitude_of_v**2)*v
print("projection of vector on v vetor = ",proj_of_a_on_v)
# Out:
# projection of vector on v vetor =  [-1.12  0.84]

# %%
a = np.array([23,45,62])
v = np.array([45,82,67])

#magnitude of 'v' vector
magnitude_of_v = np.sqrt(sum(v**2))
proj_of_a_on_v = (np.dot(a,v)/magnitude_of_v**2)*v
print("projection of vector on v vetor = ",proj_of_a_on_v)
# Out:
# projection of vector on v vetor =  [30.18242937 54.99909352 44.93828373]
